# %% [markdown]
# So, let's get to it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Temp atm.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

from sklearn.feature_selection import RFECV
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('../data/cleaned_train.csv')
print(df.shape)
df.head()
# Out:
# (1200000, 50)
#    id   age  gender  annual_income  number_of_dependents  health_score  \
# 0   0  19.0       0        10049.0                   1.0        22.599
# 1   1  39.0       0        31678.0                   3.0        15.570
# 2   2  23.0       1        25602.0                   3.0        47.178
# 3   3  21.0       1       141855.0                   2.0        10.938
# 4   4  21.0       1        39651.0                   1.0        20.376
#
#    previous_claims  vehicle_age  credit_score  insurance_duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         595.0                 3.0
# 3              1.0          0.0         367.0                 1.0
# 4              0.0          8.0         598.0                 4.0
#
#             policy_start_date  customer_feedback  smoking_status  \
# ...

# %%
#Recall that we already took whatever we wanted from time. Will go back if desired.
#And, obviously dropping id.
df.drop(['policy_start_date', 'id'], axis=1, inplace=True)
#Oh, perhaps we shoud have just done that when declaring X. Oh well

# %% [markdown]
# ## Modeling
#
# I don't expect to do anything fancy. But, you never know what 'changes' might need to be made.

# %%
X = df.drop('premium_amount', axis=1)
y = df['premium_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=26) #Relatively large test size as we
#have so much data to work with...
#Re. 26 - I like that number. Discussion not for now

ss = StandardScaler() #Temp. removed to have an easier time seeing which feature names were used.
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# 0.003592186741525616

# %% [markdown]
# Well, yeah, this could be... let's get in some rf:
#
# Oh, it's taking way too long. Will hopefully get back to it.
#
# Recall, by the way, how pretty much every feature was uniformly distributed... Yeah, that likely makes things more difficult. But, we'll see.

# %%
# lr = LinearRegression()
# rfe = RFECV(lr, step=1, cv=5
#             ,min_features_to_select=3)

# rfe = rfe.fit(X_train, y_train)

# %%
# y_pred = rfe.predict(X_test)

# r2_score(y_test, y_pred)

# %% [markdown]
# Re. forests - also taking forever. Perhaps due to the size of the data... Will try to work on these later.

# %%
# pipe = Pipeline([
#     ('rfr', RandomForestRegressor(random_state=26))
# ])

# pipe_params = {'rfr__min_samples_split' : [2,3,5]
#                ,'rfr__min_samples_leaf' : [1,2,3]
#                ,'rfr__max_features' : ['sqrt']
#               }
# #Will keep grid search to make things easier
# gs_rfr = GridSearchCV(pipe,
#                   param_grid=pipe_params,
#                   cv=None)

# gs_rfr.fit(X_train, y_train)

# print(gs_rfr.score(X_train, y_train), gs_rfr.score(X_test, y_test))
# print(gs_rfr.best_score_)
# print(gs_rfr.best_params_)
